# %%
# !ls
# Out:
# data                      dense_linear_classifer.py test.ipynb

# %%
# !python dense_linear_classifer.py
# Out:
# c value is: 1
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 0.5344
# c value is: 2
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 0.5364
# c value is: 3
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# ^C
# Traceback (most recent call last):
#   File "dense_linear_classifer.py", line 192, in <module>
#     model = fit_model(X_train, Y_train, c)
#   File "dense_linear_classifer.py", line 90, in fit_model
#     train_input.append(document_to_vector(doc))
#   File "dense_linear_classifer.py", line 63, in document_to_vector
# ...

# %%
c = [c/10 for c in range(1, 11, 1)]
c
len(c)
# Out:
# 10

# %%
# [0.776, 0.792, 0.804, 0.814, 0.826, 0.826, 0.822, 0.822, 0.82, 0.82]
# [0.754, 0.784, 0.806, 0.816, 0.82, 0.822, 0.822, 0.828, 0.828, 0.83]

# !python dense_linear_classifer-Copy1.py
# Out:
# 2000
# 1000
# 2000
# 500
# 500
# 0.842

# %%
import numpy as np
v = [1,2,3]
for i in range(3):
    v[i] /= 3
print(v)
v = [1,2,3]
v = list(np.divide(v, 3))
print(v)
# Out:
# [0.3333333333333333, 0.6666666666666666, 1.0]
# [0.3333333333333333, 0.6666666666666666, 1.0]

# %%
import numpy as np
v = [1,2,3]
a = [1,1,1]
for i in range(3):
    v[i] += a[i]
print(v)
w = [1,2,3]
a = [1,1,1]
w = np.add(w, a)
print(w)
for i in range(3):
    v[i] /= 3
w = list(np.divide(w, 3))
print(v)
print(w)
# Out:
# [2, 3, 4]
# [2 3 4]
# [0.6666666666666666, 1.0, 1.3333333333333333]
# [0.6666666666666666, 1.0, 1.3333333333333333]

# %%
[0.00011213104885711867, 0.0014828447990610334, -0.0009325319081763191, -0.004179531979378929, 0.0009045225363053865, 0.0011189276492896607, 0.0009735870532481605, -0.002343171555770108, -0.0009286758392087046, 0.01284006293292338, -0.0033285891371213462, 0.004943458027687717, 0.0018828140706593393, -0.0006364087701367735, -0.0012988142818255077, 0.0004917828931142856, 0.00038149473617942115, 0.01111281485678899, -0.0018273900392664774, 0.00025462138973774665, -0.0001141442964704451, 0.00041164013642784847, 0.00012390706279645053, 0.00016203318286325805, 0.002243738860273178, 0.0013645762351270293, -0.0026084199021173763, 0.00027525292402165593, 0.0008574660835821215, 0.00013758485246340542, -0.00026706423499072107, -0.0035537332914183646, -0.0003760235960925797, 0.0005968015739185466, 0.0008066686785190148, -0.0005365886494189946, 0.002420426789894909, 0.001974844267545547, 0.0009215517638940186, 0.0005079247869503826, -0.0001340068481605999, -0.0019944595141832304, 0.003506809864374668, -0.003442690724363747, -0.0006180868177469281, -0.001075060991752974, -0.002719747809086347, -9.861170592093632e-05, -0.0013634775695774435, -0.000771749607974326, -0.00012787653796274547, -0.0012470331879287984, 0.0017146317605432513, -0.00119733931896856, -0.0010541718143267204, -0.0009410897519113879, 0.0001658161225825077, 0.0009336775135933632, 7.268688007164916e-05, -0.0010528034171906151
660739575, 0.002110436736546509, 0.0009033377752950779, 0.00010000790227263206, 0.0015642156865668154, -0.0028204191055744244, 0.0004586280946408621, 0.003576752386862481, 0.0010311806759245698, -0.0008026224934611361, 2.3955116805001062e-05, 0.0006982491088396098, 0.0011873959043590724, -0.0012979295368357297, 0.00038463655105908773, 0.00013037946462800813, -0.002251541361787415, -0.00030749567304783006, -0.0003634305287286593, 0.00015782628155779606, -0.000773163690281708, 0.0005520551416983396, 0.0020409536008804325, 0.00029232645862134525, 0.0005176543735333608, 0.001020502834135744, -0.00013804618578948272, 0.003156149705393944, 0.0013903048119251126, -0.0009222265456372573, -0.0004849999786486422, 0.0033486307933705338, 0.0009351381111072389, -0.0012071455044795289, -0.0026143715655309735, -0.0012334523430166736, 0.00016396212478965802, -0.0008801016071706922, 0.0006803721535025688, -0.0032663099097447255, 0.000923423099537673, -0.0006182025292288104, -0.0007278677146631393, 0.00045824425923301284, -0.0009482724879040352, 0.0011721756868758241, 0.0005992774166385343, -0.0015661534525588413, -0.0019244320494157432, 0.00039088186481817783, -0.000373281149410037, 0.0020422821715257943, 0.0017807095254656483, -0.0016780793762567537, -0.0014608115039625963, 0.0008425431162441242, -0.0007177725960754271, 0.0019426355136781088, 0.001950149670470032, 0.001871038546202459, -0.0013087634183247387, -0.00034060745148073907, 0.001357239454946268, 0.0012454510991610236, 0.002368417904207732, -0.0014216228041777463, -0.002408864578073874, -0.0016989265432659655, -0.0010567435889859145, 0.0028191222895211187, 0.0015994589818016647, -0.0017726626190326881, -0.0018120907493743069, -0.002614415567328877, -0.0016849182331207674, -0.00031773824480189677, 0.005517503578586746, 0.0013460678532626015, -0.0018497578801191478, 0.0006629023677208192, 0.0004176791993192458, -0.002196542731764398, -0.003056438347086106, 0.0007400467104604057, 0.0014779024652018023, 0.0002921390197672732, -0.0007460066494734173, 0.0017232575846999664, 0.004293705107712022, -0.0032770764450169632, 0.0006122892784248692, -0.002768747206201008, -0.001638840558520272, 0.0001499285034843304, -0.0007697670989375632, -0.0016657223767050815, 0.0036355671543692437, 0.0008181890435832695, 0.0011179032222836027, -0.00045996076055100567, -0.002100944526601117, 0.00013416586008416703, -0.001977316861450073, 0.0004499174354351605, 0.0009814530544589631, 0.0009868066209794582, -0.0025632224664527484, -0.00025970221514853245]

# %%
vec  = [0] * 3
all_vec = [[1,2,3], [4,5,6]]
wd_len = 3
for one_vec in all_vec:
    vec += np.add(vec, one_vec)
    vec = np.divide(vec, wd_len) 
    
print(list(vec))
# Out:
# [1.5555555555555554, 2.111111111111111, 2.6666666666666665]

# %%
vec  = [0] * 3
all_vec = [[1,2,3], [4,5,6]]
wd_len = 3    
for i in range(3):
    for one_vec in all_vec:
        vec[i] += one_vec[i]
        vec[i] /= wd_len
print(vec)
# Out:
# [1.4444444444444444, 1.888888888888889, 2.3333333333333335]
